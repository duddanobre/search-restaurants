# %%
import pandas as pd
import matplotlib.pyplot as plt
plt.rcParams['text.usetex'] = False

import numpy as np
import seaborn as sns

import re
import folium

# %%
df = pd.read_csv("database/dadosBrutos/drive thru.csv", sep=';')
df
# Out:
#                                                   NOME  PONTUACAO  \
# 0                                  Complexo Crocobeach        4.6
# 1    Drive-Thru Clementino Fraga Patologia Clínica ...        2.3
# 2                                           McDonald's        NaN
# 3                                           McDonald's        NaN
# 4    Coco Bambu Coffee Break: Cafés, Padaria, Resta...        4.6
# ..                                                 ...        ...
# 221                                              Ceará        NaN
# 222                                          Fortaleza        NaN
# 223                     Hospital Infantil Albert Sabin        4.2
# 224                                        Ilumina Led        5.0
# 225                                          Vibe café        3.6
#
#              COMENTARIO                                              LOCAL  \
# 0    32.492 comentários  Av. Clóvis Arrais Maia, 3125 - Praia Do Futuro...
# ...

# %%
df[df['TIPO'].isna()]
# Out:
#                                                   NOME  PONTUACAO COMENTARIO  \
# 20                              Skyna by Brend Burguer        NaN        NaN
# 26                                 Churrasquinho efata        NaN        NaN
# 46                                Império dos salgados        NaN        NaN
# 50                   Marmitaria e churrasquinho Rosana        NaN        NaN
# 61                                     Galeria Frangão        NaN        NaN
# 62   Loja Oficial Mormaii Shopping RioMar Fortaleza...        NaN        NaN
# 79                                     Fortaleza Ceará        NaN        NaN
# 91                                  Universo Nerd - Ce        NaN        NaN
# 97                                     Rei Leão Outlet        NaN        NaN
# 130                                     Senhorita Pink        NaN        NaN
# 141                                         Yexb Jeans        NaN        NaN
# ...
